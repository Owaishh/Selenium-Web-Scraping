# %%
import pandas as pd
import re
import os
import datetime

# %%
os.getcwd()
# Out:
# '/var/opt/mssql'

# %%
os.chdir('/var/opt/mssql/Downloads')

# %%
import pandas as pd
import re
import os
import datetime
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
from selenium.webdriver.common.by import By
driver = webdriver.Firefox(executable_path='/var/opt/mssql/Downloads/geckodriver')

sleep(10)
driver.get('https://www.google.com/search?client=firefox-b-lm&tbs=lf:1,lf_ui:2&tbm=lcl&sxsrf=ALiCzsZDS_SAieBUJl9vr_SkR_8dvkQ5_w:1661481282173&q=coaching+institutes+in+auraiya&rflfq=1&num=10&sa=X&ved=2ahUKEwi-uv-MvOP5AhXVCrcAHd6EAfUQjGp6BAgEEAE&biw=1366&bih=614&dpr=1#rlfi=hd:;si:;mv:[[26.475635699999998,79.5182662],[26.452048899999998,79.5025209]];tbs:lrf:!1m4!1u3!2m2!3m1!1e1!1m4!1u2!2m2!2m1!1e1!2m1!1e2!2m1!1e3!3sIAE,lf:1,lf_ui:2')
# Out:
# /tmp/ipykernel_30106/2902348926.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path='/var/opt/mssql/Downloads/geckodriver')

# %%
domain = driver.find_elements(By.XPATH, '/html/body/div[6]/div/div[9]/div[2]/div/div[2]/async-local-kp/div/div/div[1]/div/div/block-component/div/div[1]/div/div/div/div[1]/div/div/div[4]/div/div[2]/div/div/span[2]')

# %%
don1 = []

# %%
n = 1
while n<=16:
    domain = driver.find_element(By.CSS_SELECTOR, 'div.dbg0pd.eDIkBe')
    sleep(3)
    domain.click()
    domain2 = driver.find_elements(By.CSS_SELECTOR, "div.wDYxhc")
    for p in range(len(domain2)):
        don2.append(domain2[p].text)
    n = n+1
    domain2 = driver.find_element(By.CSS_SELECTOR, 'span.z1asCe.rzyADb')
    sleep(3)
    domain2.click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [98], in <cell line: 2>()
#       6 domain2 = driver.find_elements(By.CSS_SELECTOR, "div.wDYxhc")
#       7 for p in range(len(domain2)):
# ----> 8     don2.append(domain2[p].text)
#       9 n = n+1
#      10 domain2 = driver.find_element(By.CSS_SELECTOR, 'span.z1asCe.rzyADb')
#
# File ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py:84, in WebElement.text(self)
#      81 @property
#      82 def text(self) -> str:
#      83     """The text of the element."""
# ---> 84     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#
# File ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# ...

# %%
opk = pd.DataFrame(don1, columns =['Business_name'], dtype = str ) 
print(opk)
# Out:
#                                          Business_name
# 0    Mahendra Educational Private Limited - Best co...
# 1              Spectrum Academy IITJEE CLASSES Auraiya
# 2    ETRICKS Academy - Best English Spoken Class of...
# 3          INVICTUS EDUCATION IIT JEE/ NEET/CBSE BOARD
# 4                                      Sankalp Academy
# ..                                                 ...
# 272                                 Sai printing press
# 273          Shivam csc center Ludphura Auraiya 206122
# 274                   Competition Era Coaching Classes
# 275                     Apex Computer Coaching Rampura
# 276                              Model Coaching Center
#
# [277 rows x 1 columns]

# %%
opk.to_csv('coaching_name.csv')

# %%
don2 = []

# %%
domain = driver.find_element(By.CSS_SELECTOR, 'div.dbg0pd.eDIkBe')
domain.click()
sleep(5)
domain2 = driver.find_elements(By.CSS_SELECTOR, "div.wDYxhc")
for p in range(len(domain2)):
    don2.append(domain2[p].text)
domain3 = driver.find_element(By.CSS_SELECTOR, 'span.z1asCe.rzyADb')
domain3.click()

# %%
don2
# Out:
# ['Spectrum Academy IITJEE CLASSES Auraiya\nDirections\nSave',
#  '4.0\n51 Google reviews\nCoaching center in Auraiya, Uttar Pradesh',
#  '',
#  'Address: 3/327, Awas Vikas Colony, Bidhuli, Auraiya, Uttar Pradesh 206122',
#  'Hours:\nOpen ⋅ Closes 8PM',
#  '',
#  "Suggest an edit\n\n\n· Own this business?\nAdd missing information\nAdd place's phone number\n\nAdd website",
#  'Questions & answers\nAsk a question\nSee all questions (1)',
#  'More photos',
#  'Write a review\nReview summary\n5\n4\n3\n2\n1\n4.0\n51 reviews\n"Very well designed syllabus and hard working staff."\n"Best coaching for jee main, advanced ,ntse, kvpy and other exams"\n"It is the best place for me It gives knowledge to success in life"',
# ...

# %%
don3 = []

# %%
domain = driver.find_elements(By.CSS_SELECTOR, 'span.YDIN4c.YrbPuc')
sleep(4)
for p in range(len(domain)):
    don3.append(domain[p].text)

# %%
don3
# Out:
# []

# %% [markdown]
# #n = 1
# while n<=16:
#     sleep(3)
#     domain = driver.find_element(By.CSS_SELECTOR, 'div.dbg0pd.eDIkBe')
#     sleep(3)
#     domain.click()
#     sleep(3)
#     domain2 = driver.find_elements(By.CSS_SELECTOR, "div.wDYxhc")
#     for p in range(len(domain2)):
#         don2.append(domain2[p].text)
#     n = n+1
#     sleep(3)
#     domain2 = driver.find_element(By.CSS_SELECTOR, 'a#pnnext')
#     sleep(3)
#     domain2.click()

# %% [markdown]
# n = 1
# while n<=16:
#     sleep(3)
#     domain = driver.find_elements(By.CSS_SELECTOR, 'div.dbg0pd.eDIkBe')
#     for p in range(len(domain)):
#         don1.append(domain[p].text)
#     n = n+1
#     sleep(3)
#     domain2 = driver.find_element(By.CSS_SELECTOR, 'a#pnnext')
#     sleep(3)
#     domain2.click()

# %%
domain = driver.find_elements(By.CSS_SELECTOR, 'div.Lui3Od.T7Wufd')
sleep(20)
for p in range(len(domain)):
    don1.append(domain[p].text)

# %%
don1
# Out:
# ['Prabhat kumar mishra #PRABHAT INC.\n5.0(26)\nCoaching Center · Veer vinay chauk\n063074 88338',
#  'Dr Prateek Mishra Math Classes\n4.7(11)\nCoaching Center · C5HV+XQP\nOpen ⋅ Closes 6PM · 080905 37270',
#  'BTFOC COACHING CLASSES\n4.8(5)\nCoaching Center · Near Sri Ram Janki temple , pawan studio Awas Mohalla, Baluha Rd\nOpen ⋅ Closes 8PM',
#  'American Institute Of English Language Pvt.Ltd.\n4.7(75)\nEnglish language school · 1st Floor Riddhi Siddhi Complex Above Sahara Bank, Bahraich Rd\nOpen ⋅ Closes 7PM · 080907 85841',
#  'Balrampur institute of information technology and Excellent Competition Point Balrampur\n4.8(24)\nEducational institution · Ambedkar tiraha, Tulsipur - Sirsiya - Bilaspur Road\nOpen ⋅ Closes 7PM',
#  'Sarv Coaching Centre\n3.7(3)\nCoaching Center · C5P8+6GH, Stadium Rd',
#  'Blp coaching centre\n2.5(2)\nCoaching Center · C5GV+PX3',
#  'Kewal Coaching classes juwathan balrampur\n5.0(1)\nCoaching Center · C5JJ+76R, SH 1A\nOpen 24 hours',
# ...

# %%
# Out:
# ['Prabhat kumar mishra #PRABHAT INC.\n5.0(26)\nCoaching Center · Veer vinay chauk\n063074 88338', 'Dr Prateek Mishra Math Classes\n4.7(11)\nCoaching Center · C5HV+XQP\nOpen ⋅ Closes 6PM · 080905 37270', 'BTFOC COACHING CLASSES\n4.8(5)\nCoaching Center · Near Sri Ram Janki temple , pawan studio Awas Mohalla, Baluha Rd\nOpen ⋅ Closes 8PM', 'American Institute Of English Language Pvt.Ltd.\n4.7(75)\nEnglish language school · 1st Floor Riddhi Siddhi Complex Above Sahara Bank, Bahraich Rd\nOpen ⋅ Closes 7PM · 080907 85841', 'Balrampur institute of information technology and Excellent Competition Point Balrampur\n4.8(24)\nEducational institution · Ambedkar tiraha, Tulsipur - Sirsiya - Bilaspur Road\nOpen ⋅ Closes 7PM', 'Sarv Coaching Centre\n3.7(3)\nCoaching Center · C5P8+6GH, Stadium Rd', 'Blp coaching centre\n2.5(2)\nCoaching Center · C5GV+PX3', 'Kewal Coaching classes juwathan balrampur\n5.0(1)\nCoaching Center · C5JJ+76R, SH 1A\nOpen 24 hours', 'KAUTILYA BALRAMPUR\n3.0(2)\nCoaching Cent
# ...

# %%
opk = pd.DataFrame(don1, columns =['Business_name'], dtype = str ) 
opk.to_csv('balrampur.csv')

# %%
opk = pd.read_csv('balrampur.csv')

# %%
opk
# Out:
#      Unnamed: 0                                      Business_name
# 0             0  Prabhat kumar mishra #PRABHAT INC.\n5.0(26)\nC...
# 1             1  Dr Prateek Mishra Math Classes\n4.7(11)\nCoach...
# 2             2  BTFOC COACHING CLASSES\n4.8(5)\nCoaching Cente...
# 3             3  American Institute Of English Language Pvt.Ltd...
# 4             4  Balrampur institute of information technology ...
# ..          ...                                                ...
# 115         115  Mohammad Haleem\n5.0(2)\nCoaching Center · G-1...
# 116         116  Best Language Classes for French | German | Sp...
# 117         117  +2 High School B Balrampur\n5.0(6)\nCollege · ...
# 118         118  Fatima Senior Secondary School\n4.2(281)\nScho...
# 119         119  Yoddha Academy of Defence\n4.9(114)\nEducation...
#
# [120 rows x 2 columns]

# %%
new = opk["Business_name"].str.split('\n', n = 1, expand = True)
opk["Business_name1"]= new[0]
opk
# Out:
#      Unnamed: 0                                      Business_name  \
# 0             0  Prabhat kumar mishra #PRABHAT INC.\n5.0(26)\nC...
# 1             1  Dr Prateek Mishra Math Classes\n4.7(11)\nCoach...
# 2             2  BTFOC COACHING CLASSES\n4.8(5)\nCoaching Cente...
# 3             3  American Institute Of English Language Pvt.Ltd...
# 4             4  Balrampur institute of information technology ...
# ..          ...                                                ...
# 115         115  Mohammad Haleem\n5.0(2)\nCoaching Center · G-1...
# 116         116  Best Language Classes for French | German | Sp...
# 117         117  +2 High School B Balrampur\n5.0(6)\nCollege · ...
# 118         118  Fatima Senior Secondary School\n4.2(281)\nScho...
# 119         119  Yoddha Academy of Defence\n4.9(114)\nEducation...
#
#                                         Business_name1
# 0                   Prabhat kumar mishra #PRABHAT INC.
# ...

# %%
new = opk["Business_name"].str.split('\n', n = 1, expand = True)
opk["rating"]= new[1]
opk
# Out:
#      Unnamed: 0                                      Business_name  \
# 0             0  Prabhat kumar mishra #PRABHAT INC.\n5.0(26)\nC...
# 1             1  Dr Prateek Mishra Math Classes\n4.7(11)\nCoach...
# 2             2  BTFOC COACHING CLASSES\n4.8(5)\nCoaching Cente...
# 3             3  American Institute Of English Language Pvt.Ltd...
# 4             4  Balrampur institute of information technology ...
# ..          ...                                                ...
# 115         115  Mohammad Haleem\n5.0(2)\nCoaching Center · G-1...
# 116         116  Best Language Classes for French | German | Sp...
# 117         117  +2 High School B Balrampur\n5.0(6)\nCollege · ...
# 118         118  Fatima Senior Secondary School\n4.2(281)\nScho...
# 119         119  Yoddha Academy of Defence\n4.9(114)\nEducation...
#
#                                         Business_name1  \
# 0                   Prabhat kumar mishra #PRABHAT INC.
# ...

# %%
new = opk["rating"].str.split('\n', n = 1, expand = True)
opk["rating1"]= new[0]
opk
# Out:
#      Unnamed: 0                                      Business_name  \
# 0             0  Prabhat kumar mishra #PRABHAT INC.\n5.0(26)\nC...
# 1             1  Dr Prateek Mishra Math Classes\n4.7(11)\nCoach...
# 2             2  BTFOC COACHING CLASSES\n4.8(5)\nCoaching Cente...
# 3             3  American Institute Of English Language Pvt.Ltd...
# 4             4  Balrampur institute of information technology ...
# ..          ...                                                ...
# 115         115  Mohammad Haleem\n5.0(2)\nCoaching Center · G-1...
# 116         116  Best Language Classes for French | German | Sp...
# 117         117  +2 High School B Balrampur\n5.0(6)\nCollege · ...
# 118         118  Fatima Senior Secondary School\n4.2(281)\nScho...
# 119         119  Yoddha Academy of Defence\n4.9(114)\nEducation...
#
#                                         Business_name1  \
# 0                   Prabhat kumar mishra #PRABHAT INC.
# ...

# %%
new = opk["rating"].str.split('\n', n = 1, expand = True)
opk["rating2"]= new[1]

new = opk["rating2"].str.split('\n', n = 1, expand = True)
opk["rating3"]= new[0]
opk
# Out:
#      Unnamed: 0                                      Business_name  \
# 0             0  Prabhat kumar mishra #PRABHAT INC.\n5.0(26)\nC...
# 1             1  Dr Prateek Mishra Math Classes\n4.7(11)\nCoach...
# 2             2  BTFOC COACHING CLASSES\n4.8(5)\nCoaching Cente...
# 3             3  American Institute Of English Language Pvt.Ltd...
# 4             4  Balrampur institute of information technology ...
# ..          ...                                                ...
# 115         115  Mohammad Haleem\n5.0(2)\nCoaching Center · G-1...
# 116         116  Best Language Classes for French | German | Sp...
# 117         117  +2 High School B Balrampur\n5.0(6)\nCollege · ...
# 118         118  Fatima Senior Secondary School\n4.2(281)\nScho...
# 119         119  Yoddha Academy of Defence\n4.9(114)\nEducation...
#
#                                         Business_name1  \
# 0                   Prabhat kumar mishra #PRABHAT INC.
# ...

# %%
new = opk["rating2"].str.split('\n', n = 1, expand = True)
opk["rating5"]= new[1]
opk
# Out:
#      Unnamed: 0                                      Business_name  \
# 0             0  Prabhat kumar mishra #PRABHAT INC.\n5.0(26)\nC...
# 1             1  Dr Prateek Mishra Math Classes\n4.7(11)\nCoach...
# 2             2  BTFOC COACHING CLASSES\n4.8(5)\nCoaching Cente...
# 3             3  American Institute Of English Language Pvt.Ltd...
# 4             4  Balrampur institute of information technology ...
# ..          ...                                                ...
# 115         115  Mohammad Haleem\n5.0(2)\nCoaching Center · G-1...
# 116         116  Best Language Classes for French | German | Sp...
# 117         117  +2 High School B Balrampur\n5.0(6)\nCollege · ...
# 118         118  Fatima Senior Secondary School\n4.2(281)\nScho...
# 119         119  Yoddha Academy of Defence\n4.9(114)\nEducation...
#
#                                         Business_name1  \
# 0                   Prabhat kumar mishra #PRABHAT INC.
# ...

# %%
opk.drop(['Unnamed: 0','Business_name','rating','rating2'], axis = 1, inplace = True)

# %%
opk
# Out:
#                                         Business_name1   rating1  \
# 0                   Prabhat kumar mishra #PRABHAT INC.   5.0(26)
# 1                       Dr Prateek Mishra Math Classes   4.7(11)
# 2                               BTFOC COACHING CLASSES    4.8(5)
# 3      American Institute Of English Language Pvt.Ltd.   4.7(75)
# 4    Balrampur institute of information technology ...   4.8(24)
# ..                                                 ...       ...
# 115                                    Mohammad Haleem    5.0(2)
# 116  Best Language Classes for French | German | Sp...  5.0(120)
# 117                         +2 High School B Balrampur    5.0(6)
# 118                     Fatima Senior Secondary School  4.2(281)
# 119                          Yoddha Academy of Defence  4.9(114)
#
#                                                rating3  \
# 0                   Coaching Center · Veer vinay chauk
# 1                           Coaching Center · C5HV+XQP
# ...

# %%
don7 = []

# %%
lnks = driver.find_elements(By.CLASS_NAME, "lcr4fd.S9kvJb")

for lnk in lnks:
    with open('linkfile.txt', "a") as o:
        o.write(lnk.get_attribute('href'))
        o.write('\n')
